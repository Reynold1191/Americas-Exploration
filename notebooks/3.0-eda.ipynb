# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127743_americas_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0           93763.0            48981.0          44782.0   18.184992
# 1           93219.0            48708.0          44511.0   12.115000
# 2           92664.0            48428.0          44236.0   12.160000
# 3           92117.0            48156.0          43961.0   11.485000
# 4           91626.0            47911.0          43715.0   10.816000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    6.828165                       11.0                  20.153997
# 1    6.365000                       11.0                  20.153997
# 2    5.961000                       11.0                  20.153997
# 3    5.865000                       11.0                  20.153997
# 4    5.787000                       11.0                  20.153997
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     17.004881                             8.655858
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1204, 26)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.204000e+03       1.204000e+03     1.204000e+03  1204.000000
# mean       2.126095e+07       1.075849e+07     1.050246e+07    18.184992
# std        5.505953e+07       2.791240e+07     2.714762e+07     5.728701
# min        1.510100e+04       7.336000e+03     7.765000e+03     5.900000
# 25%        1.091660e+05       5.645700e+04     5.554250e+04    13.767000
# 50%        3.422497e+06       1.764235e+06     1.658096e+06    17.602500
# 75%        1.194908e+07       5.975354e+06     5.995499e+06    22.027250
# max        3.332876e+08       1.682662e+08     1.650213e+08    37.349000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1204.000000                1204.000000                1204.000000
# mean      6.828165                  10.879921                  20.153997
# std       1.721987                   2.510386                   3.128110
# ...

# %% [markdown]
# **TODO**: Give your obervation here
#
# - Overall, describe() delineates some basic information about the dataset such as count, mean, standard deviation, ...
# - This can help us recognize some general things like what the max/min value is.
# - For example, in term of Birth Rate's data:
#     + There are 1204 lines.
#     + The mean is roughly 18.18.
#     + Standard deviation is roughly 5.73.
#     + The proportion of value under 13.767 is 25%.
#     + The proportion of value under 17.6 is 50%.
#     + The proportion of value under 22.02 is 75%.
#     + The smallest value is 5.9, and the opposite is true for 37.349.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)
data_Q1 = cleaned_df.copy()

def top_10_popu_largest(df, year, top):
    df_year = df[df['Year'] == year]
    top_list = df_year.sort_values("Total Population", ascending=False).head(top)
    return top_list

top = top_10_popu_largest(data_Q1, 2021, 10)

top.drop(['Year', 'Country'], inplace=True, axis='columns')
top
# Out:
#       Total Population  Female Population  Male Population  Birth Rate  \
# 1093       332031554.0        167550001.0      164481553.0      11.000
# 225        214326223.0        109034931.0      105291292.0      12.883
# 757        126705138.0         64849001.0       61856137.0      14.857
# 365         51516562.0         26101320.0       25415242.0      14.204
# 29          45808747.0         23130548.0       22678199.0      13.902
# 281         38226498.0         19230969.0       18995529.0       9.600
# 869         33715471.0         17020361.0       16695110.0      17.622
# 1149        28199867.0         14243056.0       13956811.0      15.877
# 337         19493184.0          9818162.0        9675022.0      11.788
# 505         17797737.0          8910902.0        8886835.0      16.817
#
#       Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 1093      10.400                       12.0                   19.18366
# ...

# %%
# YOUR CODE HERE
features_corr_10_largest = top.corr()

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(features_corr_10_largest, cmap='RdBu', center=0,ax=ax)
plt.show()

# %%
n_positive_corr = 5
top_positive_corr = features_corr_10_largest.stack().loc[features_corr_10_largest.stack() < 1.0].nlargest(n_positive_corr)

n_negative_corr = 5
top_negative_corr = features_corr_10_largest.stack().loc[features_corr_10_largest.stack() > -1.0].nsmallest(n_negative_corr)

print(top_positive_corr)
print(top_negative_corr)
# Out:
# Total Population   Female Population    0.999978
# Female Population  Total Population     0.999978
# Total Population   Male Population      0.999977
# Male Population    Total Population     0.999977
# Female Population  Male Population      0.999911
# dtype: float64
# Birth Rate                 Female life expectancy      -0.810400
# Female life expectancy     Birth Rate                  -0.810400
# Compulsory Education Dur.  Male life expectancy        -0.805114
# Male life expectancy       Compulsory Education Dur.   -0.805114
# Birth Rate                 Male life expectancy        -0.755655
# dtype: float64

# %% [markdown]
# **YOUR ANSWER**

# %% [markdown]
# Here are my observations:
# - There are some 0 correlations (e.g. Fossil Fuel Consumption and Renewable Energy Consumption) --> Same value
# - The most 3 positive correlations: Total Population - Female Population, Total Population - Male Population, Male Population - Female Population, which have the value of roughly 1 --> one increases so does the another
# - The most 3 negative correlations: Female life expectancy - Birth rate, Compulsory Education Dur. - Male life expectancy, Birth Rate - Male life expectancy --> the increase of one leads to the decrease of another

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
data_Q2 = cleaned_df.copy()
def top_popu_smallest(df, year, top):
    df_year = df[df['Year'] == year]
    top_list = df_year.sort_values("Total Population", ascending=True).head(top)
    return top_list

bot = top_popu_smallest(data_Q2, 2021, 10)

bot.drop(['Year', 'Country'], inplace=True, axis='columns')
bot
# Out:
#       Total Population  Female Population  Male Population  Birth Rate  \
# 253            31122.0            16146.0          14976.0       7.634
# 1065           45114.0            22385.0          22729.0      12.476
# 925            47606.0            24591.0          23015.0      12.125
# 561            56653.0            26844.0          29809.0      13.400
# 169            63764.0            33005.0          30759.0       7.700
# 309            68136.0            33738.0          34398.0      12.400
# 449            72412.0            36373.0          36039.0      13.326
# 1              93219.0            48708.0          44511.0      12.115
# 981           104332.0            51123.0          53209.0      12.901
# 1177          105870.0            56360.0          49510.0      11.800
#
#       Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 253        7.613                  12.000000                  20.153997
# ...

# %%
# YOUR CODE HERE
features_corr_10_smallest = bot.corr()

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(features_corr_10_smallest, cmap='RdBu', center=0,ax=ax)
plt.show()

# %%
n_positive_corr = 5
top_positive_corr = features_corr_10_smallest.stack().loc[features_corr_10_smallest.stack() < 1.0].nlargest(n_positive_corr)

n_negative_corr = 5
top_negative_corr = features_corr_10_smallest.stack().loc[features_corr_10_smallest.stack() > -1.0].nsmallest(n_negative_corr)

print(top_positive_corr)
print(top_negative_corr)
# Out:
# Employment in Agriculture(%)         Female Employment in Agriculture(%)    0.999488
# Female Employment in Agriculture(%)  Employment in Agriculture(%)           0.999488
# GDP in USD                           Agriculture value added(in USD)        0.999063
# Agriculture value added(in USD)      GDP in USD                             0.999063
# Total Population                     Female Population                      0.994769
# dtype: float64
# Female Employment in Industry(%)  Unemployment(%)                    -0.905365
# Unemployment(%)                   Female Employment in Industry(%)   -0.905365
# Total Population                  Female Employment in Industry(%)   -0.749769
# Female Employment in Industry(%)  Total Population                   -0.749769
# Male Population                   Female Employment in Industry(%)   -0.749070
# dtype: float64

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?

# %% [markdown]
# Here are my observations:
# - There are some 0 correlations (e.g. Fossil Fuel Consumption and National Income per Capita) --> Same value.
# - The most 3 positive correlations: Employment in Agriculture(%) - Female Employment in Agriculture(%), GDP in USD - Agriculture value added(in USD), Total Population - Female Population, which have the value of roughly 1 --> one increases so does the another.
# - The most 3 negative correlations: Female Employment in Industry(%) - Unemployment(%), Total Population - Female Employment in Industry(%), Male Population - Female Employment in Industry(%) --> the increase of one leads to the decrease of another.

# %% [markdown]
# Final Observations for these two questions:
# - It is also clear that there are some differences between top largest and smallest countries in feature correlations.
# - Some columns can be eleminated based on these criteria:
#     + Couples have value that roughly 0.
#     + Context: Is these features related to the context, if yes, should consider whether drop or not.
#     + Possibility of later changes: if some features can be changed in the future, should not drop.
#     + General impact: some features may not affect the target, however, it has a huge impact on each other.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate    Country
# 22       28.940357  Guatemala
# 24       27.961714      Haiti
# 25       27.421750   Honduras
# 7        26.289464    Bolivia
# 5        24.881107     Belize

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate              Country
# 16       10.081113             Dominica
# 24        9.555292                Haiti
# 40        9.377899              Uruguay
# 33        9.339327  St. Kitts and Nevis
# 4         9.075256             Barbados

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
#
# - Overall, Dominica and Haiti have the highest proportion in both Death and Birth rate.
# - However, the category of Birth rate is significantly higher than that of Death rate.
# - In conclusion, this region witnesses an upward trend in population.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# <font color=lightgreen>**Context**</font>: Male and Female
#
# <font color=lightgreen>**Question**</font>: What are the countries having the highest gap between male and female?

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)
# Male Population
# Female Population 
OQ1_avg_male_df = pd.DataFrame()
OQ1_avg_total_df = pd.DataFrame()
OQ1_avg_avg_df = pd.DataFrame()

OQ1_avg_male_df["Male Population"] = cleaned_df.groupby("Country")["Male Population"].mean()
OQ1_avg_total_df["Total Population"] = cleaned_df.groupby("Country")["Total Population"].mean()


OQ1_avg_avg_df["Country"] = OQ1_avg_male_df.index  

OQ1_avg_male_df.reset_index(drop=True, inplace=True)
OQ1_avg_total_df.reset_index(drop=True, inplace=True)


OQ1_avg_avg_df["Avg.Sex"] = (OQ1_avg_male_df["Male Population"] / OQ1_avg_total_df["Total Population"])

OQ1_avg_avg_df.sort_values("Avg.Sex", inplace=True, ascending=False)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ1_avg_avg_df.head(), x="Country", y= "Avg.Sex")

plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ1_avg_avg_df.tail(), x="Country", y= "Avg.Sex")

# %% [markdown]
# **MY OBSERVATIONS**:
# - It is likely that no country has the dominated male ratio
# - Instead, most countries have the higher female percentage

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# <font color=lightgreen>**Context**</font>: As we know, education plays a vital role in society.
#
# <font color=lightgreen>**Question**</font>: What is the level of each country?

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)
# School enrollment, primary
# School enrollment, tertiary
# Primary completion rate
# Literacy rate
#OW2 means own question 2

OQ2_avg_primary_df = pd.DataFrame()
OQ2_avg_tertiary_df = pd.DataFrame()
OQ2_avg_completion_df = pd.DataFrame()
OQ2_avg_literacy_df = pd.DataFrame()
OQ2_avg_avg_df = pd.DataFrame()

OQ2_avg_primary_df["School enrollment, primary"] = cleaned_df.groupby("Country")["School enrollment, primary"].mean()
OQ2_avg_tertiary_df["School enrollment, tertiary"] = cleaned_df.groupby("Country")["School enrollment, tertiary"].mean()
OQ2_avg_completion_df["Primary completion rate"] = cleaned_df.groupby("Country")["Primary completion rate"].mean()
OQ2_avg_literacy_df["Literacy rate"] = cleaned_df.groupby("Country")["Literacy rate"].mean()

OQ2_avg_avg_df["Country"] = OQ2_avg_primary_df.index  

OQ2_avg_primary_df.reset_index(drop=True, inplace=True)
OQ2_avg_tertiary_df.reset_index(drop=True, inplace=True)
OQ2_avg_completion_df.reset_index(drop=True, inplace=True)
OQ2_avg_literacy_df.reset_index(drop=True, inplace=True)

OQ2_avg_avg_df["Avg.Education"] = (OQ2_avg_primary_df["School enrollment, primary"] + OQ2_avg_tertiary_df["School enrollment, tertiary"] 
                                   + OQ2_avg_completion_df["Primary completion rate"] + OQ2_avg_literacy_df["Literacy rate"]) / 4

OQ2_avg_avg_df.sort_values("Avg.Education", inplace=True, ascending=False)

# %%
OQ2_avg_avg_df.head()
# Out:
#           Country  Avg.Education
# 1       Argentina      95.252595
# 39  United States      89.708141
# 13       Colombia      89.680020
# 12          Chile      89.142915
# 32    Puerto Rico      88.890074

# %%
OQ2_avg_avg_df.tail()
# Out:
#       Country  Avg.Education
# 23     Guyana      79.278093
# 28  Nicaragua      79.148129
# 26    Jamaica      78.385264
# 25   Honduras      76.847030
# 22  Guatemala      76.224040

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ2_avg_avg_df.head(), x="Country", y= "Avg.Education")

plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ2_avg_avg_df.tail(), x="Country", y= "Avg.Education")

# %% [markdown]
# **MY OBSERVATIONS**:
# - It is likely clear that in Americas: Argentina, the US, Colombia Country, Chile and Peurto Rico are the 5 regions that have the best educational accessibility
# - Argentina has the highest data alongside others, which are comparable, roughly 89

# %% [markdown]
# ## Making your own question 03? (1.5 points)

# %% [markdown]
# <font color=lightgreen>**Context**</font>: Cacbon dioxide
#
# <font color=lightgreen>**Question**</font>: Which countries emit the most ratio of cacbon in their industry?

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
#Renewable Energy Consumption (%)
#Fossil Fuel Consumption (%)
#OW3 means own question 3

OQ3_avg_RE_df = pd.DataFrame()
OQ3_avg_FF_df = pd.DataFrame()
OQ3_avg_avg_df = pd.DataFrame()

OQ3_avg_RE_df["Renewable Energy Consumption (%)"] = cleaned_df.groupby("Country")["Renewable Energy Consumption (%)"].mean()
OQ3_avg_FF_df["Fossil Fuel Consumption (%)"] = cleaned_df.groupby("Country")["Fossil Fuel Consumption (%)"].mean()

OQ3_avg_avg_df["Country"] = OQ3_avg_RE_df.index 

OQ3_avg_RE_df.reset_index(drop=True, inplace=True)
OQ3_avg_FF_df.reset_index(drop=True, inplace=True)

OQ3_avg_avg_df["Avg.CO2"] = (OQ3_avg_RE_df["Renewable Energy Consumption (%)"] - OQ3_avg_FF_df["Fossil Fuel Consumption (%)"]) / 2

OQ3_avg_avg_df.sort_values("Avg.CO2", inplace=True, ascending=False)

# %%
OQ3_avg_avg_df.head()
# Out:
#       Country    Avg.CO2
# 24      Haiti  21.346096
# 30   Paraguay  10.997596
# 22  Guatemala   7.744761
# 28  Nicaragua   1.000464
# 25   Honduras  -1.839317

# %%
OQ3_avg_avg_df.tail()
# Out:
#                 Country    Avg.CO2
# 26              Jamaica -34.496604
# 1             Argentina -35.372446
# 27               Mexico -35.579355
# 39        United States -35.759159
# 37  Trinidad and Tobago -43.654042

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ3_avg_avg_df.head(), x="Country", y= "Avg.CO2")

plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ3_avg_avg_df.tail(), x="Country", y= "Avg.CO2")

# %% [markdown]
# **MY OBSERVATIONS**:
# - It can be seen that most of countries in Americas prefer renewable energy than fossil fuel one

# %% [markdown]
# ## Making your own question 04? (1.5 points)

# %% [markdown]
# <font color=lightgreen>**Context**</font>: Let's continue, we will find some data about employment
#
# <font color=lightgreen>**Question**</font>: What are the countries providing the most employment

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
#Employment in Industry(%)
#Employment in Agriculture(%)
#Unemployment(%)
#OW4 means own question 4

OQ4_avg_Ind_df = pd.DataFrame()
OQ4_avg_Agri_df = pd.DataFrame()
OQ4_avg_Unemp_df = pd.DataFrame()
OQ4_avg_avg_df = pd.DataFrame()

OQ4_avg_Ind_df["Employment in Industry(%)"] = cleaned_df.groupby("Country")["Employment in Industry(%)"].mean()
OQ4_avg_Agri_df["Employment in Agriculture(%)"] = cleaned_df.groupby("Country")["Employment in Agriculture(%)"].mean()
OQ4_avg_Unemp_df["Unemployment(%)"] = cleaned_df.groupby("Country")["Unemployment(%)"].mean()

OQ4_avg_avg_df["Country"] =  OQ4_avg_Ind_df.index  # Gán lại cột "Country"

OQ4_avg_Ind_df.reset_index(drop=True, inplace=True)
OQ4_avg_Agri_df.reset_index(drop=True, inplace=True)
OQ4_avg_Unemp_df.reset_index(drop=True, inplace=True)

# Tính trung bình cộng của 3 chỉ số và lưu vào cột "Avg.Emp"
OQ4_avg_avg_df["Avg.Emp"] = (OQ4_avg_Ind_df["Employment in Industry(%)"] + OQ4_avg_Agri_df["Employment in Agriculture(%)"] 
                                   - OQ4_avg_Unemp_df["Unemployment(%)"]) / 3

OQ4_avg_avg_df.sort_values("Avg.Emp", inplace=True, ascending=False)

# %%
OQ4_avg_avg_df.head()
# Out:
#       Country    Avg.Emp
# 22  Guatemala  17.363344
# 7     Bolivia  16.825054
# 25   Honduras  16.586002
# 24      Haiti  15.772144
# 18    Ecuador  14.374900

# %%
OQ4_avg_avg_df.tail()
# Out:
#                   Country   Avg.Emp
# 34              St. Lucia  4.983218
# 42  Virgin Islands (U.S.)  4.137182
# 4                Barbados  4.009574
# 3            Bahamas, The  2.640546
# 32            Puerto Rico  2.612416

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ4_avg_avg_df.head(), x="Country", y= "Avg.Emp")

plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=OQ4_avg_avg_df.tail(), x="Country", y= "Avg.Emp")

# %% [markdown]
# **MY OBSERVATIONS**:
# - It can be seen that most of countries in Americas prefer renewable energy than fossil fuel one

# %% [markdown]
# ## Making your own question 05? (1.5 points)

# %% [markdown]
# <font color=lightgreen>**Context**</font>: Check the skewness
#
# <font color=lightgreen>**Question**</font>: Is the skewness positive or negative in each feature?

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
import pandas as pd
from scipy.stats import skew, kurtosis

OQ5_data = cleaned_df.drop(['Year', 'Country'], axis='columns')

skewness_values = OQ5_data.apply(lambda x: skew(x))

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
plt.figure(figsize=(10, 6))
plt.bar(OQ5_data.columns, skewness_values)
plt.xlabel("Features")
plt.ylabel("Skewness")
plt.title("Skewness of features")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **MY OBSERVATIONS**:
# - It can be seen that most of countries in Americas prefer renewable energy than fossil fuel one

# %% [markdown]
# ## Making your own question 06? (1.5 points)

# %% [markdown]
# <font color=lightgreen>**Context**</font>: Check the kurtoris
#
# <font color=lightgreen>**Question**</font>: Is the column having a Leptokurtic, Mesokurtic or Platykurtic

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
import pandas as pd
from scipy.stats import kurtosis

OQ6_data = cleaned_df.drop(['Year', 'Country'], axis='columns')

kurtosis_values = OQ6_data.apply(lambda x: kurtosis(x))

# %% [markdown]
# ### Analyzing to get the answer

# %%
plt.figure(figsize=(10, 6))
plt.bar(OQ6_data.columns, kurtosis_values)
plt.xlabel("Biến số")
plt.ylabel("Kurtosis")
plt.title("Kurtosis của các biến số")
plt.xticks(rotation=90)
plt.show()

# %%
leptokurtic_cols = kurtosis_values[kurtosis_values > 3].index
mesokurtic_cols = kurtosis_values[kurtosis_values == 3].index
platykurtic_cols = kurtosis_values[kurtosis_values < 3].index

# %% [markdown]
# Leptokurtic

# %%
leptokurtic_cols
# Out:
# Index(['Total Population', 'Female Population', 'Male Population',
#        'Female Employment in Agriculture(%)', 'GDP in USD',
#        'National Income per Capita', 'Net income from Abroad',
#        'Agriculture value added(in USD)',
#        'Electric Power Consumption(kWH per capita)',
#        'Fossil Fuel Consumption (%)', 'Female life expectancy ',
#        'School enrollment, tertiary', 'Primary completion rate',
#        'Literacy rate'],
#       dtype='object')

# %% [markdown]
# Mesokurtic

# %%
mesokurtic_cols
# Out:
# Index([], dtype='object')

# %% [markdown]
# Platykurtic

# %%
platykurtic_cols
# Out:
# Index(['Birth Rate', 'Death Rate', 'Compulsory Education Dur.',
#        'Employment in Industry(%)', 'Employment in Agriculture(%)',
#        'Female Employment in Industry(%)', 'Unemployment(%)',
#        'Renewable Energy Consumption (%)', 'Male life expectancy',
#        'School enrollment, primary'],
#       dtype='object')

# %% [markdown]
# **MY OBSERVATIONS**:
# - Heavy-tailed
# - Most columns having a high value of kurtoris are almost related to economy

# %% [markdown]
# ## Making your own question 07? (1.5 points)

# %% [markdown]
# <font color=lightgreen>**Context**</font>: Check the kurtoris
#
# <font color=lightgreen>**Question**</font>: Is the column having a Leptokurtic, Mesokurtic or Platykurtic

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
df_year = cleaned_df[cleaned_df['Year'] == 2021]
OQ7_Q1 = df_year['Birth Rate'].quantile(0.25)
OQ7_Q3 = df_year['Birth Rate'].quantile(0.75)

# %% [markdown]
# ### Analyzing to get the answer

# %%
IQR = OQ7_Q3 - OQ7_Q1

lower_bound = OQ7_Q1 - 1.5 * IQR
upper_bound = OQ7_Q3 + 1.5 * IQR

outliers = df_year[(df_year['Birth Rate'] < lower_bound) | (df_year['Birth Rate'] > upper_bound)]

# %%
print("Countries with exceptionally high or low birth rates:")
print(outliers)
# Out:
# Countries with exceptionally high or low birth rates:
# Empty DataFrame
# Columns: [Total Population, Female Population, Male Population, Birth Rate, Death Rate, Compulsory Education Dur., Employment in Industry(%), Employment in Agriculture(%), Female Employment in Agriculture(%), Female Employment in Industry(%), Unemployment(%), GDP in USD, National Income per Capita, Net income from Abroad, Agriculture value added(in USD), Electric Power Consumption(kWH per capita), Renewable Energy Consumption (%), Fossil Fuel Consumption (%), Male life expectancy, Female life expectancy , School enrollment, primary, School enrollment, tertiary, Primary completion rate, Literacy rate, Year, Country]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# **MY OBSERVATIONS**:
# - Heavy-tailed
# - Most columns having a high value of kurtoris are almost related to economy
